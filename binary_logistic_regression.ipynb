# %% [markdown]
# # Binary Logistic Regression / Classification
#
# ## Background
# Binary classification is one of the most fundamental and common tasks in machine learning and deep learning.
# At its core, it's a supervised learning problem where the goal is to categorize input data into one of two possible classes or categories.
# Think of it as teaching a machine to make a "yes" or "no" decision.
# Examples of binary classification's applications are:
#
# - Spam Detection: Classifying an email as either 'spam' or 'not spam'.
# - Medical Diagnosis: Determining if a patient has a certain disease.
# - Credit Scoring: Deciding whether a loan applicant is a 'good credit risk' or a 'bad credit risk'.
#
# A sigmoid activated multi-input, single-output linear model is a decent candidate for this job.
# In this practice, you'll train such a model to categorize samples from a toy dataset into two classes.
#
# ## Objectives
# - Train a simple neural network model.
#     - Apply sigmoid activation on a linear model.
#     - Implement binary cross entropy evaluation.
#     - Practice vectorized computing.
# - Assess model's performance using a variety of metrics.
#
#
# ## Exercises:
#
# 1. <font color=#582C83>(5%) Data Pre-Processing</font>
# 2. <font color=#582C83>(10%) Model Creation</font>
# 3. <font color=#582C83>(20%) Model Assessment</font>
# 4. <font color=#582C83>(10%) Gradient of BCE Loss</font>
# 5. <font color=#582C83>(30%) Gradient Descent Model Optimization</font>
# 6. <font color=#582C83>(25%) Classification Metrics</font>

# %% [markdown]
# ## 1. Load and Pre-Process Training Dataset
#
# The dataset,
# $$\mathcal{D} = \{\mathbf{X}, \mathbf{y}\} = \begin{bmatrix} ^{(1)} \mathbf{x} & ^{(1)} y \\ ^{(2)} \mathbf{x} & ^{(2)} y \\ \vdots \\ ^{(M)} \mathbf{x} & ^{(M)} y \end{bmatrix}$$
# consists $M$ samples.
#
# Each sample has $N$ features: $^{(i)} \mathbf{x} = [^{(i)} x_1, ^{(i)} x_2, \dots, ^{(i)} x_N]$ and is labeled as $^{(i)} y \in \{0, 1\}$, where $i \in \{1, 2, ..., M\}$.
#
# In this practice, we make a toy dataset using [scikit-learn](https://scikit-learn.org/stable/index.html)'s [datasets](https://scikit-learn.org/stable/api/sklearn.datasets.html) module.
# The dataset has $M=2048$ samples, and $N=2$ features.

# %%
from sklearn.datasets import make_blobs
import numpy as np
import matplotlib.pyplot as plt

features_raw, labels_raw = make_blobs(n_samples=2048, centers=np.array([[5, 5], [7, 8]]), cluster_std=1.0, random_state=3321)
# Visualize the raw data
plt.scatter(
    features_raw[:, 0], # feature 1 values (x coords)
    features_raw[:, 1], # feature 2 values (y coords)
    s=5*np.ones(labels_raw.size), # marker size all set to 1
    c=labels_raw, # colorized labels: 0:blue, 1:red
    cmap='coolwarm'  # color map
)

# %% [markdown]
# ### <font color=#582C83>(5%) Exercise 1: Data Pre-Processing</font>
# 1. In machine learning, it is prefered to scale features into the same range: $[0, 1]$.
# 2. To avoid dimension mismatch, reshape features and labels array into two dimensions is recommended.

# %%
### START CODING HERE ### (≈ 2 lines of code)
features_train = features_raw / features_raw.max(axis=0)  # Scale features to [0, 1]
labels_train = labels_raw.reshape(-1, 1) # Reshape labels to be a column vector
### END CODING HERE ### 

# Sanity check
print(f"Samples of pre-processed features:\n {features_train[-4:]}")
print(f"Samples of pre-processed labels:\n {labels_train[-4:]}")  # Print last 4 samples of features and labels
print(f"Shape of pre-processed features:\n {features_train.shape}.")
print(f"Shape of pre-processed labels:\n {labels_train.shape}")  # Print shapes of features and labels   

# Visualize
plt.scatter(
    features_train[:, 0], 
    features_train[:, 1], 
    s=5*np.ones(labels_train.size), 
    c=labels_train, 
    cmap='coolwarm'  # color map
)
# Out:
# Samples of pre-processed features:
#  [[0.60810041 0.36828791]
#  [0.85139165 0.63786153]
#  [0.57346525 0.38949334]
#  [0.77146837 0.71406137]]
# Samples of pre-processed labels:
#  [[0]
#  [1]
#  [0]
#  [1]]
# Shape of pre-processed features:
#  (2048, 2).
# Shape of pre-processed labels:
#  (2048, 1)

# %% [markdown]
# **Expected Outcomes**:
# ```console
# Samples of pre-processed features:
#  [[0.60810041 0.36828791]
#  [0.85139165 0.63786153]
#  [0.57346525 0.38949334]
#  [0.77146837 0.71406137]]
# Samples of pre-processed labels:
#  [[0]
#  [1]
#  [0]
#  [1]]
# Shape of pre-processed features:
#  (2048, 2).
# Shape of pre-processed labels:
#  (2048, 1)
# ```

# %% [markdown]
# ## 2. Create a Non-linear Multi-Input Single-Output Model
# Let's create a nonlinear model by applying a sigmoid function to the output of a linear model.
#
# $$\mathbf{\hat{y}} = \sigma (\mathbf{X} \cdot \mathbf{w}^T + \mathbf{b}) = \sigma(\mathbf{Z})$$
#
# The sigmoid function can be represented as,
#
# $$\sigma(\mathbf{Z}) = \frac{1}{1 + e^{-\mathbf{Z}}}$$
#
# The linear part of the model is governed by a parameter vector
# $$\mathbf{w} = [w_1, w_2, ..., w_N]_{(1, N)}$$
#
# and a bias vector
# $$\mathbf{b} = \begin{bmatrix} b \\ b \\ \vdots \\ b \end{bmatrix}_{(M, 1)}$$
#
# And, in this practice $M=2048$ and $N=2$
#
# ### <font color=#582C83>(10%) Exercise 2: Model Creation</font>
# Let's translate math to code.

# %%
def forward(in_features, weights, bias):
    """
    Compute the linear combination of inputs and weights plus bias.
    
    Args:
        in_features (np.ndarray): Input features of shape (M, N).
        weights (np.ndarray): Weights of shape (1, N).
        bias (float): Bias term.  
    Returns:
        predictions: Linear combination result of shape (M, 1).
    """
    ### START CODING HERE ### (≈ 2 lines of code)
    def sigmoid(z):
        return 1 / (1 + np.exp(-z))
    predictions = sigmoid((in_features @ weights.T + bias))  
    return predictions
    ### END CODING HERE ###

# Sanity check
w_dummy = np.array([[1.2, -2.3]])
b_dummy = 1.0
print(f"Samples of dummy prediction:\n {forward(features_train, w_dummy, b_dummy)[-4:]}")  # Print last 4 samples of dummy prediction

# Visualize dummy model decision boundary
plt.scatter(features_train[:, 0], features_train[:, 1], s=5*np.ones(labels_train.size), c=labels_train, cmap='coolwarm')
# Create a meshgrid of points over the feature space
xx, yy = np.meshgrid(np.linspace(0., 1., 300),
                     np.linspace(0., 1., 300))
zz = w_dummy[0, 0] * xx + w_dummy[0, 1] * yy + b_dummy - 0.5
plt.contourf(xx, yy, zz, levels=[-np.inf, 0, np.inf], colors=['blue', 'red'], alpha=0.25)
# Out:
# Samples of dummy prediction:
#  [[0.70737278]
#  [0.63519949]
#  [0.68833004]
#  [0.5703847 ]]

# %% [markdown]
# **Expected Outcomes**:
# >
# ```console
# Samples of dummy prediction:
#  [[0.70737278]
#  [0.63519949]
#  [0.68833004]
#  [0.5703847 ]]
# ```

# %% [markdown]
# ## 3. Evaluate Model
# As same as the linear regression, we need to evaluate model performance.
# It is OK to use a Mean Squared Error (MSE) function to compute the model loss.
# It is **recommended** to use a Binary Cross Entropy (BCE) function to assess the model for a binary classification problem.
# Binary Cross Entropy (BCE) is a differentiable metric.
# $$\mathcal{L}(\mathbf{\hat{y}}, \mathbf{y}) = \frac{1}{M} \Sigma [-\mathbf{y} \log \hat{\mathbf{y}} - (1 - \mathbf{y}) \log(1 - \hat{\mathbf{y}})]$$
#
# There are other useful metrics, such as accuracy. But they are not differentiable.
# Let $TP$ be number of true positive predictions, $TN$ be number of true negative predictions, $FP$ be number of false positive predictions, $FN$ be number of false negative predictions.
# The accuracy can be calculated by:
# $$Accuracy = \frac{TP + TN}{TP+FP+TN+FN}$$
#
# ### <font color=#582C83>(20%) Exercise 3: Model Assessment</font>
# 1. Evaluate model loss with BCE.
# 2. Assess model predictions accuracy.

# %%
def bce_loss(predictions, labels):
    """
    Compute the Binary Cross Entropy (BCE) loss.
    
    Args:
        predictions (np.ndarray): Predicted probabilities of shape (M, 1).
        labels (np.ndarray): True binary labels of shape (M, 1).
    Returns:
        loss: BCE loss value (float).
    """
    ### START CODING HERE ### (≈ 1 line)
    loss = -labels * np.log(predictions) - (1 - labels) * np.log(1 - predictions)
    return loss.mean()
    ### END CODING HERE ###

def accuracy(predictions, labels):
    """
    Compute the accuracy of predictions.
    
    Args:
        predictions (np.ndarray): Predicted probabilities of shape (M, 1).
        labels (np.ndarray): True binary labels of shape (M, 1).
    Returns:
        acc: Accuracy value (float).
    """
    ### START CODING HERE ### (≈ 2 lines)
    predicted_classes = (predictions >= 0.5).astype(int)  # Convert probabilities to binary classes
    acc = np.mean(predicted_classes == labels)  # Calculate accuracy
    return acc
    ### END CODING HERE ###

# Sanity check
preds_dummy = forward(features_train, w_dummy, b_dummy)
print(f"Dummy model BCE loss: {bce_loss(preds_dummy, labels_train)}")
print(f"Dummy model accuracy: {accuracy(preds_dummy, labels_train) * 100}%")
# Out:
# Dummy model BCE loss: 0.8189666983092332
# Dummy model accuracy: 42.67578125%

# %% [markdown]
# **Expected Output**:
# >
# ```console
# Dummy model BCE loss: 0.8189666983092332
# Dummy model accuracy: 42.67578125%
# ```

# %% [markdown]
# ## 4. Compute Gradient of Loss
# Compute gradient of the BCE loss:
#
# $$\frac{\partial \mathcal{L}}{\partial \mathbf{w}} = \begin{bmatrix} \frac{\partial \mathcal{L}}{\partial w_1} & \frac{\partial \mathcal{L}}{\partial w_2} & \dots & \frac{\partial \mathcal{L}}{\partial w_N} \end{bmatrix} = \frac{1}{M} (\hat{\mathbf{y}} - \mathbf{y})^T \cdot \mathbf{X}$$
# $$\frac{\partial \mathcal{L}}{\partial b}  = \overline{\hat{\mathbf{y}} - \mathbf{y}} $$
#
# ### <font color=#582C83>(10%) Exercise 4: Gradient of BCE Loss</font>

# %%
def gradient(predictions, labels, in_features):
    """
    Compute the gradient of the BCE loss with respect to weights and bias.
    
    Args:
        predictions (np.ndarray): Predicted probabilities of shape (M, 1).
        labels (np.ndarray): True binary labels of shape (M, 1).
        in_features (np.ndarray): Input features of shape (M, N).
    Returns:
        dw: Gradient with respect to weights of shape (1, N).
        db: Gradient with respect to bias (float).
    """
    ### START CODING HERE ### (≈ 3 lines of code)
    M = 2048  # Number of samples
    dw = 1 / labels.shape[0] * ((predictions - labels).T @ in_features)  # Gradient w.r.t. weights
    db = np.mean(predictions - labels)  # Gradient w.r.t. bias
    return dw, db
    ### END CODING HERE ###

# Sanity check
dw_dummy, db_dummy = gradient(preds_dummy, labels_train, features_train)
print(f"Dummy model gradient w.r.t. weights: {dw_dummy}, shape: {dw_dummy.shape}")
print(f"Dummy model gradient w.r.t. bias: {db_dummy}")
# Out:
# Dummy model gradient w.r.t. weights: [[ 0.01011904 -0.01882587]], shape: (1, 2)
# Dummy model gradient w.r.t. bias: 0.10192657501589689

# %% [markdown]
# **Expected Output**:
# >
# ```console
# Dummy model gradient w.r.t. weights: [[ 0.01011904 -0.01882587]], shape: (1, 2)
# Dummy model gradient w.r.t. bias: 0.10192657501589689
# ```

# %% [markdown]
# ## 5. Update Model Parameters
#
#
# By tweaking the model parameters along the gradient a small step (learning rate, $\alpha$) iteratively, we expect to bring the BCE loss down to a reasonable scale.
#
# - $\text{Initialize } \mathbf{w} \text{ and } b$
# - $\text{Repeat until converge}$
#     - $\mathbf{w} = \mathbf{w} - \alpha \frac{\partial \mathcal{L}}{\partial \mathbf{w}}$
#     - $b = b - \alpha \frac{\partial \mathcal{L}}{\partial b}$
#
#
#
# ### <font color=#582C83>(30%) Exercise 5: Gradient Descent Model Optimization</font>
# 1. Initialize weights and bias
# 2. Set learning rate and number of iterations
# 3. Repeat following steps:
#
#     1. Make predictions
#     2. Assess model
#     3. Compute gradient of loss
#     4. Update weights and bias
#
# <font color=red>**Note: bring training accuracy over 95% within 10000 iterations**</font>

# %%
# START CODING HERE ### (≈ 10 lines of code)
# Initialize parameters
w = np.random.normal(0, 1e-4, (1, features_train.shape[1])) # Initialize weights
b = np.random.normal(0, 1e-4) # Initialize bias

# Set hyperparameters
learning_rate = 0.5
num_iters = 10000

# Reserve loss and accuracy storage
losses_train = []
accuracies_train = []

# Training loop
for i in range(num_iters):
    print("in_features shape:", features_train.shape)
    print("weights shape:", w.shape)
    print("weights.T shape:", w.T.shape)

    preds_train = forward(features_train, w, b)  # Make predictions
    loss_train = bce_loss(preds_train, labels_train)  # Assess model loss
    acc_train = accuracy(preds_train, labels_train)  # Assess model accuracy
    print(f"Iteration {i+1}/{num_iters}, Loss: {loss_train:.4f}, Accuracy: {acc_train*100:.2f}%")
    losses_train.append(loss_train)
    accuracies_train.append(acc_train)
    dw, db = gradient(preds_train, labels_train,features_train)  # Compute gradient of loss
    w = w - learning_rate * dw  # Update weights
    b = b - learning_rate * db  # Update bias

### END CODING HERE ###

# Plot training loss and accuracy
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(losses_train, label='Training Loss')
plt.xlabel('Iteration')
plt.ylabel('BCE Loss')
plt.title('Training Loss over Iterations')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(np.array(accuracies_train) * 100, label='Training Accuracy', color='orange')
plt.xlabel('Iteration')
plt.ylabel('Accuracy (%)')
plt.title('Training Accuracy over Iterations')
plt.legend()
# Out:
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 1/10000, Loss: 0.6931, Accuracy: 50.00%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 2/10000, Loss: 0.6898, Accuracy: 50.00%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 3/10000, Loss: 0.6870, Accuracy: 50.00%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 4/10000, Loss: 0.6845, Accuracy: 50.00%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 5/10000, Loss: 0.6822, Accuracy: 50.00%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 6/10000, Loss: 0.6800, Accuracy: 50.00%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 7/10000, Loss: 0.6778, Accuracy: 50.00%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 8/10000, Loss: 0.6758, Accuracy: 50.00%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9/10000, Loss: 0.6737, Accuracy: 50.00%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 10/10000, Loss: 0.6717, Accuracy: 50.00%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 11/10000, Loss: 0.6698, Accuracy: 50.00%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 12/10000, Loss: 0.6678, Accuracy: 50.10%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 13/10000, Loss: 0.6659, Accuracy: 50.20%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 14/10000, Loss: 0.6639, Accuracy: 50.39%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 15/10000, Loss: 0.6620, Accuracy: 50.83%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 16/10000, Loss: 0.6601, Accuracy: 51.22%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 17/10000, Loss: 0.6582, Accuracy: 51.86%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 18/10000, Loss: 0.6563, Accuracy: 53.03%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 19/10000, Loss: 0.6544, Accuracy: 53.96%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 20/10000, Loss: 0.6526, Accuracy: 55.03%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 21/10000, Loss: 0.6507, Accuracy: 56.20%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 22/10000, Loss: 0.6489, Accuracy: 57.42%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 23/10000, Loss: 0.6470, Accuracy: 58.79%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 24/10000, Loss: 0.6452, Accuracy: 60.11%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 25/10000, Loss: 0.6434, Accuracy: 61.33%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 26/10000, Loss: 0.6416, Accuracy: 63.09%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 27/10000, Loss: 0.6398, Accuracy: 64.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 28/10000, Loss: 0.6380, Accuracy: 66.50%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 29/10000, Loss: 0.6362, Accuracy: 67.87%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 30/10000, Loss: 0.6344, Accuracy: 69.53%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 31/10000, Loss: 0.6327, Accuracy: 71.14%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 32/10000, Loss: 0.6309, Accuracy: 72.46%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 33/10000, Loss: 0.6292, Accuracy: 73.29%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 34/10000, Loss: 0.6274, Accuracy: 74.12%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 35/10000, Loss: 0.6257, Accuracy: 75.29%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 36/10000, Loss: 0.6240, Accuracy: 76.17%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 37/10000, Loss: 0.6223, Accuracy: 76.86%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 38/10000, Loss: 0.6206, Accuracy: 77.54%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 39/10000, Loss: 0.6189, Accuracy: 78.71%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 40/10000, Loss: 0.6172, Accuracy: 79.39%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 41/10000, Loss: 0.6156, Accuracy: 80.13%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 42/10000, Loss: 0.6139, Accuracy: 80.66%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 43/10000, Loss: 0.6123, Accuracy: 81.40%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 44/10000, Loss: 0.6106, Accuracy: 81.88%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 45/10000, Loss: 0.6090, Accuracy: 82.32%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 46/10000, Loss: 0.6074, Accuracy: 82.71%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 47/10000, Loss: 0.6057, Accuracy: 83.40%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 48/10000, Loss: 0.6041, Accuracy: 84.23%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 49/10000, Loss: 0.6025, Accuracy: 84.47%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 50/10000, Loss: 0.6009, Accuracy: 84.86%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 51/10000, Loss: 0.5994, Accuracy: 85.55%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 52/10000, Loss: 0.5978, Accuracy: 85.84%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 53/10000, Loss: 0.5962, Accuracy: 86.33%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 54/10000, Loss: 0.5947, Accuracy: 86.96%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 55/10000, Loss: 0.5931, Accuracy: 87.45%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 56/10000, Loss: 0.5916, Accuracy: 87.84%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 57/10000, Loss: 0.5901, Accuracy: 88.04%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 58/10000, Loss: 0.5885, Accuracy: 88.23%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 59/10000, Loss: 0.5870, Accuracy: 88.53%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 60/10000, Loss: 0.5855, Accuracy: 88.82%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 61/10000, Loss: 0.5840, Accuracy: 89.21%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 62/10000, Loss: 0.5825, Accuracy: 89.70%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 63/10000, Loss: 0.5810, Accuracy: 89.84%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 64/10000, Loss: 0.5796, Accuracy: 89.99%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 65/10000, Loss: 0.5781, Accuracy: 90.28%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 66/10000, Loss: 0.5766, Accuracy: 90.48%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 67/10000, Loss: 0.5752, Accuracy: 90.58%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 68/10000, Loss: 0.5737, Accuracy: 90.72%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 69/10000, Loss: 0.5723, Accuracy: 91.02%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 70/10000, Loss: 0.5709, Accuracy: 91.26%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 71/10000, Loss: 0.5694, Accuracy: 91.36%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 72/10000, Loss: 0.5680, Accuracy: 91.50%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 73/10000, Loss: 0.5666, Accuracy: 91.65%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 74/10000, Loss: 0.5652, Accuracy: 91.85%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 75/10000, Loss: 0.5638, Accuracy: 91.99%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 76/10000, Loss: 0.5624, Accuracy: 92.09%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 77/10000, Loss: 0.5610, Accuracy: 92.14%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 78/10000, Loss: 0.5597, Accuracy: 92.19%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 79/10000, Loss: 0.5583, Accuracy: 92.38%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 80/10000, Loss: 0.5570, Accuracy: 92.48%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 81/10000, Loss: 0.5556, Accuracy: 92.53%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 82/10000, Loss: 0.5543, Accuracy: 92.63%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 83/10000, Loss: 0.5529, Accuracy: 92.77%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 84/10000, Loss: 0.5516, Accuracy: 92.82%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 85/10000, Loss: 0.5503, Accuracy: 92.82%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 86/10000, Loss: 0.5489, Accuracy: 92.97%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 87/10000, Loss: 0.5476, Accuracy: 93.07%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 88/10000, Loss: 0.5463, Accuracy: 93.16%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 89/10000, Loss: 0.5450, Accuracy: 93.41%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 90/10000, Loss: 0.5437, Accuracy: 93.51%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 91/10000, Loss: 0.5425, Accuracy: 93.55%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 92/10000, Loss: 0.5412, Accuracy: 93.80%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 93/10000, Loss: 0.5399, Accuracy: 93.90%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 94/10000, Loss: 0.5387, Accuracy: 94.04%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 95/10000, Loss: 0.5374, Accuracy: 93.99%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 96/10000, Loss: 0.5361, Accuracy: 94.09%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 97/10000, Loss: 0.5349, Accuracy: 94.14%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 98/10000, Loss: 0.5337, Accuracy: 94.14%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 99/10000, Loss: 0.5324, Accuracy: 94.19%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 100/10000, Loss: 0.5312, Accuracy: 94.19%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 101/10000, Loss: 0.5300, Accuracy: 94.29%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 102/10000, Loss: 0.5288, Accuracy: 94.43%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 103/10000, Loss: 0.5276, Accuracy: 94.43%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 104/10000, Loss: 0.5264, Accuracy: 94.43%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 105/10000, Loss: 0.5252, Accuracy: 94.43%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 106/10000, Loss: 0.5240, Accuracy: 94.43%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 107/10000, Loss: 0.5228, Accuracy: 94.48%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 108/10000, Loss: 0.5216, Accuracy: 94.58%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 109/10000, Loss: 0.5204, Accuracy: 94.58%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 110/10000, Loss: 0.5193, Accuracy: 94.58%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 111/10000, Loss: 0.5181, Accuracy: 94.53%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 112/10000, Loss: 0.5170, Accuracy: 94.53%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 113/10000, Loss: 0.5158, Accuracy: 94.58%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 114/10000, Loss: 0.5147, Accuracy: 94.68%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 115/10000, Loss: 0.5135, Accuracy: 94.73%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 116/10000, Loss: 0.5124, Accuracy: 94.73%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 117/10000, Loss: 0.5113, Accuracy: 94.73%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 118/10000, Loss: 0.5102, Accuracy: 94.78%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 119/10000, Loss: 0.5090, Accuracy: 94.73%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 120/10000, Loss: 0.5079, Accuracy: 94.73%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 121/10000, Loss: 0.5068, Accuracy: 94.78%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 122/10000, Loss: 0.5057, Accuracy: 94.73%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 123/10000, Loss: 0.5046, Accuracy: 94.82%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 124/10000, Loss: 0.5035, Accuracy: 94.87%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 125/10000, Loss: 0.5025, Accuracy: 94.82%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 126/10000, Loss: 0.5014, Accuracy: 94.87%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 127/10000, Loss: 0.5003, Accuracy: 94.87%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 128/10000, Loss: 0.4992, Accuracy: 94.92%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 129/10000, Loss: 0.4982, Accuracy: 94.97%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 130/10000, Loss: 0.4971, Accuracy: 94.97%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 131/10000, Loss: 0.4961, Accuracy: 94.97%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 132/10000, Loss: 0.4950, Accuracy: 95.02%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 133/10000, Loss: 0.4940, Accuracy: 95.07%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 134/10000, Loss: 0.4929, Accuracy: 95.07%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 135/10000, Loss: 0.4919, Accuracy: 95.17%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 136/10000, Loss: 0.4909, Accuracy: 95.17%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 137/10000, Loss: 0.4899, Accuracy: 95.17%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 138/10000, Loss: 0.4888, Accuracy: 95.17%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 139/10000, Loss: 0.4878, Accuracy: 95.17%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 140/10000, Loss: 0.4868, Accuracy: 95.17%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 141/10000, Loss: 0.4858, Accuracy: 95.17%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 142/10000, Loss: 0.4848, Accuracy: 95.17%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 143/10000, Loss: 0.4838, Accuracy: 95.17%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 144/10000, Loss: 0.4828, Accuracy: 95.17%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 145/10000, Loss: 0.4819, Accuracy: 95.21%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 146/10000, Loss: 0.4809, Accuracy: 95.26%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 147/10000, Loss: 0.4799, Accuracy: 95.31%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 148/10000, Loss: 0.4789, Accuracy: 95.36%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 149/10000, Loss: 0.4780, Accuracy: 95.36%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 150/10000, Loss: 0.4770, Accuracy: 95.31%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 151/10000, Loss: 0.4761, Accuracy: 95.36%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 152/10000, Loss: 0.4751, Accuracy: 95.36%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 153/10000, Loss: 0.4742, Accuracy: 95.36%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 154/10000, Loss: 0.4732, Accuracy: 95.36%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 155/10000, Loss: 0.4723, Accuracy: 95.36%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 156/10000, Loss: 0.4713, Accuracy: 95.36%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 157/10000, Loss: 0.4704, Accuracy: 95.36%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 158/10000, Loss: 0.4695, Accuracy: 95.36%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 159/10000, Loss: 0.4686, Accuracy: 95.36%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 160/10000, Loss: 0.4676, Accuracy: 95.41%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 161/10000, Loss: 0.4667, Accuracy: 95.41%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 162/10000, Loss: 0.4658, Accuracy: 95.46%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 163/10000, Loss: 0.4649, Accuracy: 95.46%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 164/10000, Loss: 0.4640, Accuracy: 95.41%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 165/10000, Loss: 0.4631, Accuracy: 95.41%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 166/10000, Loss: 0.4622, Accuracy: 95.41%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 167/10000, Loss: 0.4613, Accuracy: 95.46%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 168/10000, Loss: 0.4605, Accuracy: 95.56%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 169/10000, Loss: 0.4596, Accuracy: 95.56%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 170/10000, Loss: 0.4587, Accuracy: 95.56%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 171/10000, Loss: 0.4578, Accuracy: 95.51%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 172/10000, Loss: 0.4570, Accuracy: 95.51%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 173/10000, Loss: 0.4561, Accuracy: 95.51%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 174/10000, Loss: 0.4552, Accuracy: 95.56%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 175/10000, Loss: 0.4544, Accuracy: 95.56%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 176/10000, Loss: 0.4535, Accuracy: 95.56%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 177/10000, Loss: 0.4527, Accuracy: 95.56%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 178/10000, Loss: 0.4518, Accuracy: 95.61%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 179/10000, Loss: 0.4510, Accuracy: 95.61%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 180/10000, Loss: 0.4502, Accuracy: 95.61%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 181/10000, Loss: 0.4493, Accuracy: 95.61%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 182/10000, Loss: 0.4485, Accuracy: 95.61%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 183/10000, Loss: 0.4477, Accuracy: 95.56%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 184/10000, Loss: 0.4469, Accuracy: 95.56%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 185/10000, Loss: 0.4460, Accuracy: 95.56%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 186/10000, Loss: 0.4452, Accuracy: 95.51%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 187/10000, Loss: 0.4444, Accuracy: 95.51%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 188/10000, Loss: 0.4436, Accuracy: 95.51%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 189/10000, Loss: 0.4428, Accuracy: 95.51%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 190/10000, Loss: 0.4420, Accuracy: 95.51%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 191/10000, Loss: 0.4412, Accuracy: 95.51%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 192/10000, Loss: 0.4404, Accuracy: 95.51%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 193/10000, Loss: 0.4396, Accuracy: 95.51%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 194/10000, Loss: 0.4388, Accuracy: 95.51%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 195/10000, Loss: 0.4380, Accuracy: 95.56%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 196/10000, Loss: 0.4373, Accuracy: 95.56%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 197/10000, Loss: 0.4365, Accuracy: 95.56%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 198/10000, Loss: 0.4357, Accuracy: 95.56%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 199/10000, Loss: 0.4350, Accuracy: 95.56%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 200/10000, Loss: 0.4342, Accuracy: 95.51%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 201/10000, Loss: 0.4334, Accuracy: 95.51%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 202/10000, Loss: 0.4327, Accuracy: 95.51%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 203/10000, Loss: 0.4319, Accuracy: 95.51%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 204/10000, Loss: 0.4312, Accuracy: 95.51%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 205/10000, Loss: 0.4304, Accuracy: 95.51%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 206/10000, Loss: 0.4297, Accuracy: 95.51%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 207/10000, Loss: 0.4289, Accuracy: 95.51%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 208/10000, Loss: 0.4282, Accuracy: 95.51%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 209/10000, Loss: 0.4274, Accuracy: 95.56%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 210/10000, Loss: 0.4267, Accuracy: 95.56%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 211/10000, Loss: 0.4260, Accuracy: 95.56%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 212/10000, Loss: 0.4252, Accuracy: 95.56%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 213/10000, Loss: 0.4245, Accuracy: 95.56%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 214/10000, Loss: 0.4238, Accuracy: 95.51%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 215/10000, Loss: 0.4231, Accuracy: 95.51%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 216/10000, Loss: 0.4224, Accuracy: 95.51%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 217/10000, Loss: 0.4216, Accuracy: 95.56%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 218/10000, Loss: 0.4209, Accuracy: 95.56%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 219/10000, Loss: 0.4202, Accuracy: 95.56%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 220/10000, Loss: 0.4195, Accuracy: 95.56%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 221/10000, Loss: 0.4188, Accuracy: 95.56%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 222/10000, Loss: 0.4181, Accuracy: 95.56%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 223/10000, Loss: 0.4174, Accuracy: 95.56%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 224/10000, Loss: 0.4167, Accuracy: 95.56%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 225/10000, Loss: 0.4161, Accuracy: 95.56%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 226/10000, Loss: 0.4154, Accuracy: 95.61%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 227/10000, Loss: 0.4147, Accuracy: 95.65%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 228/10000, Loss: 0.4140, Accuracy: 95.65%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 229/10000, Loss: 0.4133, Accuracy: 95.65%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 230/10000, Loss: 0.4127, Accuracy: 95.65%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 231/10000, Loss: 0.4120, Accuracy: 95.70%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 232/10000, Loss: 0.4113, Accuracy: 95.70%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 233/10000, Loss: 0.4106, Accuracy: 95.70%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 234/10000, Loss: 0.4100, Accuracy: 95.70%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 235/10000, Loss: 0.4093, Accuracy: 95.70%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 236/10000, Loss: 0.4087, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 237/10000, Loss: 0.4080, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 238/10000, Loss: 0.4074, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 239/10000, Loss: 0.4067, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 240/10000, Loss: 0.4061, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 241/10000, Loss: 0.4054, Accuracy: 95.70%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 242/10000, Loss: 0.4048, Accuracy: 95.70%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 243/10000, Loss: 0.4041, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 244/10000, Loss: 0.4035, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 245/10000, Loss: 0.4029, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 246/10000, Loss: 0.4022, Accuracy: 95.70%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 247/10000, Loss: 0.4016, Accuracy: 95.70%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 248/10000, Loss: 0.4010, Accuracy: 95.70%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 249/10000, Loss: 0.4003, Accuracy: 95.70%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 250/10000, Loss: 0.3997, Accuracy: 95.70%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 251/10000, Loss: 0.3991, Accuracy: 95.70%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 252/10000, Loss: 0.3985, Accuracy: 95.70%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 253/10000, Loss: 0.3979, Accuracy: 95.70%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 254/10000, Loss: 0.3973, Accuracy: 95.70%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 255/10000, Loss: 0.3967, Accuracy: 95.70%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 256/10000, Loss: 0.3960, Accuracy: 95.70%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 257/10000, Loss: 0.3954, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 258/10000, Loss: 0.3948, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 259/10000, Loss: 0.3942, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 260/10000, Loss: 0.3936, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 261/10000, Loss: 0.3930, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 262/10000, Loss: 0.3924, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 263/10000, Loss: 0.3919, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 264/10000, Loss: 0.3913, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 265/10000, Loss: 0.3907, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 266/10000, Loss: 0.3901, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 267/10000, Loss: 0.3895, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 268/10000, Loss: 0.3889, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 269/10000, Loss: 0.3884, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 270/10000, Loss: 0.3878, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 271/10000, Loss: 0.3872, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 272/10000, Loss: 0.3866, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 273/10000, Loss: 0.3861, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 274/10000, Loss: 0.3855, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 275/10000, Loss: 0.3849, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 276/10000, Loss: 0.3844, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 277/10000, Loss: 0.3838, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 278/10000, Loss: 0.3833, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 279/10000, Loss: 0.3827, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 280/10000, Loss: 0.3822, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 281/10000, Loss: 0.3816, Accuracy: 95.75%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 282/10000, Loss: 0.3811, Accuracy: 95.80%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 283/10000, Loss: 0.3805, Accuracy: 95.80%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 284/10000, Loss: 0.3800, Accuracy: 95.80%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 285/10000, Loss: 0.3794, Accuracy: 95.80%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 286/10000, Loss: 0.3789, Accuracy: 95.80%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 287/10000, Loss: 0.3783, Accuracy: 95.80%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 288/10000, Loss: 0.3778, Accuracy: 95.80%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 289/10000, Loss: 0.3773, Accuracy: 95.80%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 290/10000, Loss: 0.3767, Accuracy: 95.85%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 291/10000, Loss: 0.3762, Accuracy: 95.85%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 292/10000, Loss: 0.3757, Accuracy: 95.85%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 293/10000, Loss: 0.3752, Accuracy: 95.85%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 294/10000, Loss: 0.3746, Accuracy: 95.85%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 295/10000, Loss: 0.3741, Accuracy: 95.85%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 296/10000, Loss: 0.3736, Accuracy: 95.85%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 297/10000, Loss: 0.3731, Accuracy: 95.85%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 298/10000, Loss: 0.3725, Accuracy: 95.85%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 299/10000, Loss: 0.3720, Accuracy: 95.90%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 300/10000, Loss: 0.3715, Accuracy: 95.90%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 301/10000, Loss: 0.3710, Accuracy: 95.90%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 302/10000, Loss: 0.3705, Accuracy: 95.90%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 303/10000, Loss: 0.3700, Accuracy: 95.90%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 304/10000, Loss: 0.3695, Accuracy: 95.90%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 305/10000, Loss: 0.3690, Accuracy: 95.90%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 306/10000, Loss: 0.3685, Accuracy: 95.90%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 307/10000, Loss: 0.3680, Accuracy: 95.90%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 308/10000, Loss: 0.3675, Accuracy: 95.90%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 309/10000, Loss: 0.3670, Accuracy: 95.90%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 310/10000, Loss: 0.3665, Accuracy: 95.90%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 311/10000, Loss: 0.3660, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 312/10000, Loss: 0.3655, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 313/10000, Loss: 0.3650, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 314/10000, Loss: 0.3645, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 315/10000, Loss: 0.3640, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 316/10000, Loss: 0.3636, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 317/10000, Loss: 0.3631, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 318/10000, Loss: 0.3626, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 319/10000, Loss: 0.3621, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 320/10000, Loss: 0.3616, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 321/10000, Loss: 0.3612, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 322/10000, Loss: 0.3607, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 323/10000, Loss: 0.3602, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 324/10000, Loss: 0.3597, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 325/10000, Loss: 0.3593, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 326/10000, Loss: 0.3588, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 327/10000, Loss: 0.3583, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 328/10000, Loss: 0.3579, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 329/10000, Loss: 0.3574, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 330/10000, Loss: 0.3570, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 331/10000, Loss: 0.3565, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 332/10000, Loss: 0.3560, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 333/10000, Loss: 0.3556, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 334/10000, Loss: 0.3551, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 335/10000, Loss: 0.3547, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 336/10000, Loss: 0.3542, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 337/10000, Loss: 0.3538, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 338/10000, Loss: 0.3533, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 339/10000, Loss: 0.3529, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 340/10000, Loss: 0.3524, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 341/10000, Loss: 0.3520, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 342/10000, Loss: 0.3516, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 343/10000, Loss: 0.3511, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 344/10000, Loss: 0.3507, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 345/10000, Loss: 0.3502, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 346/10000, Loss: 0.3498, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 347/10000, Loss: 0.3494, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 348/10000, Loss: 0.3489, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 349/10000, Loss: 0.3485, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 350/10000, Loss: 0.3481, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 351/10000, Loss: 0.3476, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 352/10000, Loss: 0.3472, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 353/10000, Loss: 0.3468, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 354/10000, Loss: 0.3464, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 355/10000, Loss: 0.3459, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 356/10000, Loss: 0.3455, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 357/10000, Loss: 0.3451, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 358/10000, Loss: 0.3447, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 359/10000, Loss: 0.3443, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 360/10000, Loss: 0.3439, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 361/10000, Loss: 0.3434, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 362/10000, Loss: 0.3430, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 363/10000, Loss: 0.3426, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 364/10000, Loss: 0.3422, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 365/10000, Loss: 0.3418, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 366/10000, Loss: 0.3414, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 367/10000, Loss: 0.3410, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 368/10000, Loss: 0.3406, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 369/10000, Loss: 0.3402, Accuracy: 95.95%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 370/10000, Loss: 0.3398, Accuracy: 95.90%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 371/10000, Loss: 0.3394, Accuracy: 95.90%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 372/10000, Loss: 0.3390, Accuracy: 95.90%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 373/10000, Loss: 0.3386, Accuracy: 95.90%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 374/10000, Loss: 0.3382, Accuracy: 95.90%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 375/10000, Loss: 0.3378, Accuracy: 95.90%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 376/10000, Loss: 0.3374, Accuracy: 95.90%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 377/10000, Loss: 0.3370, Accuracy: 95.90%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 378/10000, Loss: 0.3366, Accuracy: 95.90%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# ...
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9876/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9877/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9878/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9879/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9880/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9881/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9882/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9883/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9884/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9885/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9886/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9887/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9888/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9889/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9890/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9891/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9892/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9893/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9894/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9895/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9896/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9897/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9898/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9899/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9900/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9901/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9902/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9903/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9904/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9905/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9906/10000, Loss: 0.1092, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9907/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9908/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9909/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9910/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9911/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9912/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9913/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9914/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9915/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9916/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9917/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9918/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9919/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9920/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9921/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9922/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9923/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9924/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9925/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9926/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9927/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9928/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9929/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9930/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9931/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9932/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9933/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9934/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9935/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9936/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9937/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9938/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9939/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9940/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9941/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9942/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9943/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9944/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9945/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9946/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9947/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9948/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9949/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9950/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9951/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9952/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9953/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9954/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9955/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9956/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9957/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9958/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9959/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9960/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9961/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9962/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9963/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9964/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9965/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9966/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9967/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9968/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9969/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9970/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9971/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9972/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9973/10000, Loss: 0.1091, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9974/10000, Loss: 0.1090, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9975/10000, Loss: 0.1090, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9976/10000, Loss: 0.1090, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9977/10000, Loss: 0.1090, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9978/10000, Loss: 0.1090, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9979/10000, Loss: 0.1090, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9980/10000, Loss: 0.1090, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9981/10000, Loss: 0.1090, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9982/10000, Loss: 0.1090, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9983/10000, Loss: 0.1090, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9984/10000, Loss: 0.1090, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9985/10000, Loss: 0.1090, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9986/10000, Loss: 0.1090, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9987/10000, Loss: 0.1090, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9988/10000, Loss: 0.1090, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9989/10000, Loss: 0.1090, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9990/10000, Loss: 0.1090, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9991/10000, Loss: 0.1090, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9992/10000, Loss: 0.1090, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9993/10000, Loss: 0.1090, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9994/10000, Loss: 0.1090, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9995/10000, Loss: 0.1090, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9996/10000, Loss: 0.1090, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9997/10000, Loss: 0.1090, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9998/10000, Loss: 0.1090, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 9999/10000, Loss: 0.1090, Accuracy: 96.34%
# in_features shape: (2048, 2)
# weights shape: (1, 2)
# weights.T shape: (2, 1)
# Iteration 10000/10000, Loss: 0.1090, Accuracy: 96.34%

# %%
# Visualize decision boundary after training
plt.scatter(features_train[:, 0], features_train[:, 1], s=5*np.ones(labels_train.size), c=labels_train, cmap='coolwarm')
xx, yy = np.meshgrid(np.linspace(0., 1., 300),
                     np.linspace(0., 1., 300))
zz = w[0, 0] * xx + w[0, 1] * yy + b - 0.5
plt.contourf(xx, yy, zz, levels=[-np.inf, 0, np.inf], colors=['blue', 'red'], alpha=0.25)
plt.title('Decision Boundary after Training')
# Out:
# Text(0.5, 1.0, 'Decision Boundary after Training')

# %% [markdown]
# ## 5. Evaluate Model with a New Dataset
# Let's generate a similar dataset using [make_blobs](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html#sklearn.datasets.make_blobs) as used in the beginning of this practice.
# Make predictions and evaluate model with this newly generated dataset.

# %%
# Accuracy on training data
X_raw, y_raw = make_blobs(n_samples=512, centers=np.array([[5, 5], [7, 8]]), cluster_std=1.0,)
features_test = X_raw / X_raw.max(axis=0)  # Scale features to [-1, 1]
labels_test = y_raw.reshape(-1, 1)  # Reshape labels to be a column vector

# Visualize test data
plt.scatter(
    features_test[:, 0], 
    features_test[:, 1], 
    s=5*np.ones(labels_test.size), 
    c=labels_test, 
    cmap='managua'  # color map
)
# Visualize decision boundary on test data
plt.contourf(xx, yy, zz, levels=[-np.inf, 0, np.inf], colors=['orange', 'cyan'], alpha=0.25)
plt.title('Decision Boundary on Test Data')
# Out:
# Text(0.5, 1.0, 'Decision Boundary on Test Data')

# %% [markdown]
# Besides accuracy, a handful of metrics are useful to evaluate how sensitive/precise/balance the model is.
# A confusion matrix is a handy tool to visualize these metrics.

# %%
# Confusion Matrix for Test Data
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

preds_test = forward(features_test, w, b)
cm_test = confusion_matrix(labels_test, (preds_test >= 0.5).astype(int))
disp_test = ConfusionMatrixDisplay(confusion_matrix=cm_test, display_labels=[0, 1])
disp_test.plot(cmap='PuRd')
plt.title('Confusion Matrix - Test Data')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix - Test Data')

# %% [markdown]
# ### <font color=#582C83>(25%) Exercise 6: Classification Metrics</font>
# According to your confusion matrix on the **test dataset**. Please calculate the following metrics and write your answers below.
# > Let $0$ be negative, and $1$ be positive.
#
# - `Accuracy`= 0.934
# - `Recall`= 0.888
# - `Precision`= 0.992
# - `F1 Score`= 0.937
#
# <font color=#582C83>Assume the model is used by the quality control department in a factory to detect defective products (class 1).
# Please briefly state (2 sentences maximum) why or why not this model is good for this job.</font>
# > Please write down your answer below.
#
# Because most of the model's predictions were correct - either true positive or true negative - the model is decent at this job, but not the best. Because the model is meant to identify defective products to ensure the customer's satisfaction, the model's tendency to make more false negative predictions - incorrrectly classifying something that's defective as not defective - makes it less useful than if it were to make more false positive predictions - incorrectly classifying a product as defective when it's actually alright.

# %%
accuracy = (254+224)/(254+224+2+32) 
recall = 254 / (254+32)
precision = 254 /(254+2)
f1_score = 2 * (precision * recall) / (precision + recall)
print (accuracy, recall, precision, f1_score)
# Out:
# 0.93359375 0.8881118881118881 0.9921875 0.9372693726937269

# %% [markdown]
# # Congratulations! You have finished this assignment!
